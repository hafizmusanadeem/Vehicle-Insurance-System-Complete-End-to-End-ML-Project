# %% [markdown]
# # **Scope of this Notebook is to only push a local data to MongoDB so then we can pull our data from an actual database.**

# %%
import pandas as pd
import pymongo

df = pd.read_csv('data.csv')
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
df.shape
# Out:
# (381109, 12)

# %%
df['Driving_License'].unique
# Out:
# <bound method Series.unique of 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 381104    1
# 381105    1
# 381106    1
# 381107    1
# 381108    1
# Name: Driving_License, Length: 381109, dtype: int64>

# %%
# data should be converted into dictiionary before we push it to MongoDB
data = df.to_dict(orient= 'records')

# %%
DB_NAME = 'Proj1'
COLLECTION_NAME = 'Proj1-Data'
CONNECTION_URL = "mongodb+srv://musanad04_db_user:sgTqUvPcpdgMazWB@cluster0.wycaohz.mongodb.net/?appName=Cluster0"

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

# %%
rec = collection.insert_many(data)

# %%
print(type(rec))
# Out:
# <class 'pymongo.results.InsertManyResult'>
